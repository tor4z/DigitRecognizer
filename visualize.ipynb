# %%
import data
import matplotlib.pyplot as plt
# %matplotlib inline

train_data = data.data_reader('/data/cwj/data/digit/train.csv')
# Out:
# (42000,)

# %%
from matplotlib.ticker import FormatStrFormatter
import numpy as np

labels = train_data[:, 0]

print(labels.shape)

bins = np.arange(11)
plt.hist(labels, width=0.8, bins=bins-0.4)
plt.xticks(np.arange(10))
plt.show()

print(labels)
# Out:
# (42000,)
# [1 0 1 ... 7 6 9]
